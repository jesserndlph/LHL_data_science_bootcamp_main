# %%
import pandas as pd
data = pd.read_csv('my_document.csv')

# %%
data
# Out:
#      Unnamed: 0  ApplicantIncome  CoapplicantIncome  Credit_History  \
# 0           350             9083                0.0             1.0
# 1           377             4310                0.0             1.0
# 2           163             4167             1447.0             1.0
# 3           609             2900                0.0             1.0
# 4           132             2718                0.0             1.0
# ..          ...              ...                ...             ...
# 149         535             2550             2042.0             1.0
# 150         468              210             2917.0             1.0
# 151         582             3166                0.0             1.0
# 152         291             4400                0.0             0.0
# 153          75             3750                0.0             1.0
#
#      Dependents  Education_Not Graduate  Gender_Male  LoanAmount_log  \
# 0             0                       0            1        5.429346
# ...

# %%
data.Loan_Amount_Term.describe()
# Out:
# count    154.000000
# mean     350.805195
# std       52.365992
# min       84.000000
# 25%      360.000000
# 50%      360.000000
# 75%      360.000000
# max      480.000000
# Name: Loan_Amount_Term, dtype: float64

# %%
data.Loan_Amount_Term.sum()
# Out:
# 54024.0

# %%
import matplotlib.pyplot as plt
plt.hist(data.Loan_Amount_Term);
