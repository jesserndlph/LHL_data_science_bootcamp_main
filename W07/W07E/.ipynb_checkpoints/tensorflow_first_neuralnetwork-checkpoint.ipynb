# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
network = models.Sequential()
network.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))
network.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 10s 173us/sample - loss: 0.1989 - accuracy: 0.9408
# Epoch 2/5
# 60000/60000 [==============================] - 10s 162us/sample - loss: 0.0741 - accuracy: 0.9766
# Epoch 3/5
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.0478 - accuracy: 0.9845
# Epoch 4/5
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.0355 - accuracy: 0.9884
# Epoch 5/5
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.0257 - accuracy: 0.9913

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc, 'test_loss', test_loss)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test_acc: 0.9788 test_loss 0.07448417834982392
