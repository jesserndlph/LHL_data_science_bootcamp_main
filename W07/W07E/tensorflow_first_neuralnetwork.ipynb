# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
network = models.Sequential()
network.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))
network.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=15, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 10s 171us/sample - loss: 0.1964 - accuracy: 0.9422
# Epoch 2/15
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.0722 - accuracy: 0.9775
# Epoch 3/15
# 60000/60000 [==============================] - 10s 160us/sample - loss: 0.0458 - accuracy: 0.9852
# Epoch 4/15
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.0350 - accuracy: 0.9886
# Epoch 5/15
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.0273 - accuracy: 0.9910
# Epoch 6/15
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.0225 - accuracy: 0.9923
# Epoch 7/15
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.0195 - accuracy: 0.9930
# Epoch 8/15
# 60000/60000 [==============================] - 10s 170us/sample - loss: 0.0148 - accuracy: 0.9952
# Epoch 9/15
# 60000/60000 [==============================] - 10s 162us/sample - loss: 0.0141 - accuracy: 0.9953
# Epoch 10/15
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.0158 - accuracy: 0.9952
# Epoch 11/15
# 60000/60000 [==============================] - 12s 203us/sample - loss: 0.0129 - accuracy: 0.9958
# Epoch 12/15
# 60000/60000 [==============================] - 12s 199us/sample - loss: 0.0119 - accuracy: 0.9962
# Epoch 13/15
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0117 - accuracy: 0.9964
# Epoch 14/15
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.0129 - accuracy: 0.9959
# Epoch 15/15
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.0069 - accuracy: 0.9977

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc, 'test_loss', test_loss)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test_acc: 0.9801 test_loss 0.10323438199929191
