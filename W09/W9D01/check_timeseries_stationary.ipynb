# %%
from pandas import read_csv
from matplotlib import pyplot
import pandas as pd
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-total-female-births.csv'
series = pd.read_csv(url)
series.plot()
pyplot.show()

# %%
# non-stationary time series
from pandas import read_csv
from matplotlib import pyplot
airline_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
series = read_csv(airline_url, header=0, index_col=0)
series.plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv(url, header=0, index_col=0)
series.hist()
pyplot.show()

# %%
from pandas import read_csv
series = read_csv(url, header=0, index_col=0)
X = series.values
split = round(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=39.763736, mean2=44.185792
# variance1=49.213410, variance2=48.708651

# %%
from pandas import read_csv
series = read_csv(airline_url, header=0, index_col=0)

# %%
series = series.reset_index()

# %%
split = round(len(series) / 2)

# %%
X1, X2 = series.iloc[0:split], series.iloc[split:]

# %%
mean1, mean2 = X1.mean(), X2.mean()
# Out:
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_2194/887398462.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean1, mean2 = X1.mean(), X2.mean()

# %%
var1, var2 = X1.var(), X2.var()
# Out:
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_2194/159529804.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   var1, var2 = X1.var(), X2.var()

# %%
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=182.902778, mean2=377.694444
# variance1=2275.694640, variance2=7471.736307

# %% [markdown]
# ### Augmented Dickey-Fuller test

# %%
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
series = read_csv(url, header=0, index_col=0, squeeze=True)
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_2194/2698616888.py in <module>
#       1 from pandas import read_csv
# ----> 2 from statsmodels.tsa.stattools import adfuller
#       3 series = read_csv(url, header=0, index_col=0, squeeze=True)
#       4 X = series.values
#       5 result = adfuller(X)
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
# same on airline dataset
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
series = read_csv(airline_url, header=0, index_col=0, squeeze=True)
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_2194/373017291.py in <module>
#       1 # same on airline dataset
#       2 from pandas import read_csv
# ----> 3 from statsmodels.tsa.stattools import adfuller
#       4 series = read_csv(airline_url, header=0, index_col=0, squeeze=True)
#       5 X = series.values
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
from numpy import log
series = read_csv('international-airline-passengers.csv', header=0, index_col=0, squeeze=True)
X = series.values
X = log(X) # log transform this time
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
