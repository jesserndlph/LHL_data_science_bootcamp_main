# %%
import pandas as pd
from prophet import Prophet

# %%
# Python
url = 'https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv'
df = pd.read_csv(url)
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet()

# %%
m.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -19.4685
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       7976.66    0.00444357       453.026           1           1      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      187       7991.33   3.47837e-05       114.938   3.253e-07       0.001      269  LS failed, Hessian reset
#      199       7992.36   0.000526128       162.677           1           1      283
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      292       7998.14   4.23891e-05       142.064   2.782e-07       0.001      436  LS failed, Hessian reset
#      299       7998.58   0.000381087       163.741      0.2361           1      447
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       8001.14   3.07041e-05       62.7479           1           1      578
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      455       8002.55   0.000448706       363.569   4.065e-06       0.001      688  LS failed, Hessian reset
#      499       8003.08    0.00238075       165.219           1           1      742
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      562       8003.49   0.000132781       167.518   1.269e-06       0.001      852  LS failed, Hessian reset
#      599       8003.62   0.000265049       114.185      0.9321      0.9321      894
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       8004.24   0.000457583       110.286           1           1     1005
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      718       8004.39    5.4143e-05       166.417    4.29e-07       0.001     1109  LS failed, Hessian reset
#      774       8004.68   4.51868e-06       67.7487   7.622e-08       0.001     1230  LS failed, Hessian reset
#      782       8004.68   2.13054e-07       63.6047      0.4077      0.4077     1243
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.204617    7.476799    8.908288
# 3266 2017-01-16  8.529628    7.807445    9.203867
# 3267 2017-01-17  8.317021    7.631917    9.025096
# 3268 2017-01-18  8.149634    7.433840    8.826269
# 3269 2017-01-19  8.161561    7.462570    8.828185

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from prophet import plot_plotly, plot_components_plotly
plot_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_10181/1971271943.py in <module>
# ----> 1 from prophet import plot_plotly, plot_components_plotly
#       2 plot_plotly(m, forecast)
#
# ImportError: cannot import name 'plot_plotly' from 'prophet' (/Users/louisrossi/opt/anaconda3/envs/mlearning/lib/python3.8/site-packages/prophet/__init__.py)
